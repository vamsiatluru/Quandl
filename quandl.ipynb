# %%
import pandas as pd
import numpy as np

# %%
import quandl

# %%
data = quandl.get("BCHARTS/BITSTAMPUSD", authtoken="9wZ7WNxgomEpVFhz7FG_")

# %%
data
# Out:
#                Open     High      Low    Close  Volume (BTC)  \
# Date
# 2011-09-13     5.80     6.00     5.65     5.97     58.371382
# 2011-09-14     5.58     5.72     5.52     5.53     61.145984
# 2011-09-15     5.12     5.24     5.00     5.13     80.140795
# 2011-09-16     4.82     4.87     4.80     4.85     39.914007
# 2011-09-17     4.87     4.87     4.87     4.87      0.300000
# 2011-09-18     4.87     4.92     4.81     4.92    119.812800
# 2011-09-19     4.90     4.90     4.90     4.90     20.000000
# 2011-09-20     4.92     5.66     4.92     5.66     89.280711
# 2011-09-21     5.70     5.79     5.66     5.66     17.629322
# 2011-09-22     5.68     5.72     5.68     5.72     43.778422
# 2011-09-23     5.70     5.72     5.70     5.72     20.680037
# 2011-09-24     5.70     5.76     5.68     5.68     90.587066
# 2011-09-25     6.05     6.05     6.05     6.05     12.220000
# 2011-09-26     6.06     6.06     4.80     4.80     39.578463
# ...

# %%
import matplotlib.pyplot as plt

# %%
data[['Weighted Price']]
# Out:
#             Weighted Price
# Date
# 2011-09-13        5.929231
# 2011-09-14        5.590798
# 2011-09-15        5.094272
# 2011-09-16        4.854515
# 2011-09-17        4.870000
# 2011-09-18        4.839576
# 2011-09-19        4.900000
# 2011-09-20        5.388054
# 2011-09-21        5.706075
# 2011-09-22        5.696960
# 2011-09-23        5.707099
# 2011-09-24        5.722494
# 2011-09-25        6.050000
# 2011-09-26        5.983073
# 2011-09-27        4.895402
# 2011-09-28        4.862498
# 2011-09-29        4.816345
# 2011-09-30        0.000000
# 2011-10-01        0.000000
# 2011-10-02        0.000000
# 2011-10-03        4.847772
# 2011-10-04        4.924737
# 2011-10-05        5.029419
# 2011-10-06        4.908846
# 2011-10-07        4.687629
# 2011-10-08        4.455536
# 2011-10-09        3.890000
# 2011-10-10        4.498302
# 2011-10-11        3.998965
# 2011-10-12        3.943964
# ...                    ...
# 2018-06-24     5987.551809
# 2018-06-25     6204.806754
# ...

# %%
plt.plot(data.index, data['Weighted Price'], 'r') 
plt.title('Bitcoin Stock Price From 2012 to Present')
plt.ylabel('Price ($)');
plt.show();
